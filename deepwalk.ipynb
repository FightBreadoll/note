# %%
import networkx as nx # 图数据挖掘

# 数据分析
import pandas as pd
import numpy as np

import random # 随机数
from tqdm import tqdm # 进度条

# 数据可视化
import matplotlib.pyplot as plt
# %matplotlib inline

plt.rcParams['font.sans-serif']=['SimHei']  # 用来正常显示中文标签  
plt.rcParams['axes.unicode_minus']=False  # 用来正常显示负号

# %%
# 导入 csv 文件定义的有向图
df = pd.read_csv('data/harrypotterkgdata.csv')

# %%
df.head()
# Out:
#      head       tail relation
# 0   C.沃林顿  斯莱特林魁地奇球队       从属
# 1   C.沃林顿      调查行动组       从属
# 2   C.沃林顿   霍格沃茨魔法学校       从属
# 3  乔治·韦斯莱     亚瑟·韦斯莱       父亲
# 4  乔治·韦斯莱        凤凰社       从属

# %%
G = nx.from_pandas_edgelist(df, "head", "tail", edge_attr=True, create_using=nx.Graph())

# %%
len(G)
# Out:
# 648

# %%
def get_randomwalk(node, path_length):
    '''
    输入起始节点和路径长度，生成随机游走节点序列
    '''
    
    random_walk = [node]
    
    for i in range(path_length-1):
        # 汇总邻接节点
        temp = list(G.neighbors(node))
        temp = list(set(temp) - set(random_walk))    
        if len(temp) == 0:
            break
        # 从邻接节点中随机选择下一个节点
        random_node = random.choice(temp)
        random_walk.append(random_node)
        node = random_node
        
    return random_walk

# %%
all_nodes = list(G.nodes())
all_nodes
# Out:
# ['C.沃林顿',
#  '斯莱特林魁地奇球队',
#  '调查行动组',
#  '霍格沃茨魔法学校',
#  '乔治·韦斯莱',
#  '亚瑟·韦斯莱',
#  '凤凰社',
#  '吉迪翁·普威特',
#  '哈利·波特',
#  '塞德瑞拉·布莱克',
#  '塞德里克·迪戈里',
#  '塞普蒂默斯·韦斯莱',
#  '奥黛丽·韦斯莱',
#  '安吉利娜·约翰逊',
#  '弗雷德·韦斯莱',
#  '弗雷德·韦斯莱二世',
#  '普威特先生',
#  '普威特夫人',
#  '普威特家族',
#  '查理·韦斯莱',
#  '格兰芬多学院',
#  '格兰芬多魁地奇球队',
#  '比利尔斯',
#  '比尔·韦斯莱',
#  '珀西·韦斯莱',
#  '纳威·隆巴顿',
#  '罗克珊·韦斯莱',
#  '罗恩·韦斯莱',
#  '芙蓉·德拉库尔',
#  '莫丽·韦斯莱',
#  '莱姆斯·卢平',
#  '费比安·普威特',
#  '赫敏·格兰杰',
#  '邓布利多军',
#  '金妮·韦斯莱',
#  '阿拉斯托·穆迪',
#  '韦斯莱家族',
#  '韦斯莱魔法把戏坊',
#  '乔治三世',
#  '亨利七世',
#  '威廉一世',
#  '维多利亚',
#  '亚伯拉罕·波特',
#  '波特家族',
#  '美国魔法国会',
#  '詹姆·波特',
#  '伪劣防御咒及防护用品侦查收缴办公室',
#  '伪劣防御咒及防护用品侦查收缴办公室主任',
#  '多米尼克·韦斯莱',
#  '禁止滥用麻瓜物品办公室',
#  '禁止滥用麻瓜物品办公室主任',
#  '穆丽尔',
#  '维克托娃·韦斯莱',
#  '罗丝·韦斯莱',
#  '英国魔法部',
#  '莉莉·卢娜·波特',
#  '莫丽·韦斯莱二世',
#  '莱桑德拉·亚克斯利',
#  '詹姆·小天狼星·波特',
#  '路易·韦斯莱',
#  '阿不思·西弗勒斯·波特',
#  '阿克图勒斯·布莱克二世',
#  '雨果·韦斯莱',
#  '露西·韦斯莱',
#  '魔法法律执行司',
#  '亨利·波特',
#  '威森加摩',
#  '尤菲米娅·波特',
#  '弗利蒙·波特',
#  '波特夫人，原姓弗利蒙',
#  '亨利八世',
#  '伊丽莎白一世',
#  '威廉三世',
#  '安妮·博林',
#  '玛丽一世',
#  '玛丽二世',
#  '亨利六世',
#  '伊万斯姐妹的父亲',
#  '伊万斯夫人',
#  '佩妮·伊万斯',
#  '弗农·德思礼',
#  '莉莉·伊万斯',
#  '达力·德思礼',
#  '伊万杰琳·奥平顿',
#  '伊索特·塞耶',
#  '伊尔弗莫尼魔法学校',
#  '塞耶家族',
#  '威廉·塞耶',
#  '斯图尔特家族',
#  '查威克·布特',
#  '玛莎·斯图尔特二世',
#  '莫瑞根',
#  '萨拉查·斯莱特林',
#  '葛姆蕾·冈特',
#  '詹姆·斯图尔特',
#  '雷欧娜·塞耶',
#  '雷欧娜·斯图尔特',
#  '韦伯·布特',
#  '伍德克罗夫特的汉吉斯',
#  '霍格莫德村',
#  '佩内洛·克里瓦特',
#  '克里瓦特家族',
#  '拉文克劳',
#  '佩妮·德思礼',
#  '伊万斯先生',
#  '伊万斯家庭',
#  '家庭主妇',
#  '德思礼夫人',
#  '德思礼家庭',
#  '格朗宁公司的上班族',
#  '玛姬·德思礼',
#  '兰登·肖',
#  '小亨利·肖',
#  '老亨利·肖',
#  '刚度富士·格雷维斯',
#  '珀西瓦尔·格雷维斯',
#  '卡斯提蒂·巴瑞波恩',
#  '克莱登斯·巴瑞波恩',
#  '巴瑞波恩家族',
#  '新塞勒姆慈善协会',
#  '玛丽·卢·巴瑞波恩',
#  '莫迪丝蒂·巴瑞波恩',
#  '卡洛斯·洛佩兹',
#  '卢修斯·马尔福',
#  '卢修斯·马尔福一世',
#  '安多米达·唐克斯',
#  '尼法朵拉·唐克斯',
#  '布鲁图斯·马尔福',
#  '德拉科·马尔福',
#  '德鲁埃拉·布莱克',
#  '斯科皮·马尔福',
#  '斯莱特林',
#  '泰德·唐克斯',
#  '纳西莎·布莱克',
#  '罗道夫斯·莱斯特兰奇',
#  '西格纳斯·布莱克三世',
#  '贝拉特里克斯·莱斯特兰奇',
#  '阿布拉克萨斯·马尔福',
#  '阿斯托里亚·格林格拉斯',
#  '阿曼德·马尔福',
#  '霍格沃茨魔法学校董事会',
#  '食死徒',
#  '马尔福家族',
#  '魔法部',
#  '魔法部官员',
#  '鼻涕虫俱乐部',
#  '卢多·巴格曼',
#  '奥托·巴格曼',
#  '巴格曼先生',
#  '巴格曼家庭',
#  '温布恩黄蜂队',
#  '温布恩黄蜂队击球手',
#  '英格兰魁地奇代表队击球手',
#  '魔法体育运动司司长',
#  '卢娜·洛夫古德',
#  '《唱唱反调》',
#  '拉文克劳学院',
#  '斯卡曼德家族',
#  '波尔蓬蒂娜·斯卡曼德',
#  '洛夫古德家庭',
#  '洛肯·斯卡曼德',
#  '潘多拉·洛夫古德',
#  '纽特·斯卡曼德',
#  '罗夫·斯卡曼德',
#  '莱桑德·斯卡曼德',
#  '谢诺菲留斯·洛夫古德',
#  '厄克特',
#  '厄尼·麦克米兰',
#  '安东尼·戈德斯坦',
#  '汉娜·艾博',
#  '赫奇帕奇',
#  '麦克米兰家族',
#  '吉德罗·洛哈特',
#  '作家',
#  '圣芒戈魔法伤病医院',
#  '梅林爵士团勋章',
#  '洛哈特先生',
#  '洛哈特夫人',
#  '洛哈特家庭',
#  '霍格沃茨魔法学校黑魔法防御术教授(1992年-1993年)',
#  '黑魔法防御联盟',
#  '吉德罗·洛哈特的姐姐',
#  '吉德罗·洛哈特的父亲',
#  '吉米·珀克斯',
#  '格兰芬多',
#  '珀克斯家族',
#  '阿不思·邓布利多',
#  '伊格内修斯·普威特',
#  '卢克丽霞·布莱克',
#  'S.P.E.W.',
#  '伊格诺图斯·佩弗利尔',
#  '傲罗办公室',
#  '傲罗办公室主任',
#  '奥利弗·伍德',
#  '扎卡赖斯·史密斯',
#  '斯廷奇库姆的林弗雷德',
#  '汤姆·里德尔',
#  '秋·张',
#  '米勒娃·麦格',
#  '莉莉·波特',
#  '西弗勒斯·斯内普',
#  '西莫·斐尼甘',
#  '路易斯·韦斯莱',
#  '达力的孩子',
#  '金妮·波特',
#  '鲁伯·海格',
#  '黑魔法防御术兼职讲师',
#  '哈米什·麦克法兰',
#  '职业魁地奇球员',
#  '蒙特罗斯喜鹊队',
#  '哈罗德·丁戈',
#  '埃尔德·沃普尔',
#  '埃尔芬斯通·埃尔科特',
#  '伊泽贝尔·罗斯',
#  '埃尔科特家庭',
#  '小罗伯特·麦格',
#  '老罗伯特·麦格',
#  '马尔科姆·麦格',
#  '麦格家族',
#  '埃德里奇·迪戈里',
#  '赫奇帕奇学院',
#  '赫奇帕奇魁地奇球队',
#  '迪戈里家族',
#  '塞普蒂默斯·马尔福',
#  '尼古拉斯·马尔福',
#  '魔法部部长顾问',
#  '塞蒂娜·沃贝克的母亲',
#  '厄文·瓦布尔',
#  '塞蒂娜·沃贝克',
#  '沃贝克先生',
#  '塞蒂娜·沃贝克的父亲',
#  '沃贝克夫人',
#  '夏比',
#  '霍格沃茨',
#  '多卡斯·十二树',
#  '亚里斯多德·十二树',
#  '十二树家庭',
#  '多洛雷斯·乌姆里奇',
#  '埃伦·克拉克内尔',
#  '奥福德·乌姆里奇',
#  '霍格沃茨校长',
#  '高级调查官',
#  '魔法部高级副部长',
#  '麻瓜出身登记委员会',
#  '麻瓜出身登记委员会主任',
#  '多纳汉·特姆利特',
#  '古怪姐妹演唱组',
#  '特姆利特先生',
#  '特姆利特夫人',
#  '特姆利特家庭',
#  '伍德先生',
#  '伍德夫人',
#  '普德米尔联队',
#  '奥古斯特·卢克伍德',
#  '伏地魔',
#  '神秘事务司',
#  '奥罗拉·辛尼斯塔',
#  '天文学家',
#  '天文学系',
#  '天文学系教授(早于1991年',
#  '奥赖恩·布莱克',
#  '伊尔玛·克拉布',
#  '天狼星·布莱克二世',
#  '小天狼星·布莱克',
#  '布莱克家族',
#  '帕勒克斯·布莱克',
#  '梅拉尼娅·麦克米兰',
#  '沃尔布加·布莱克',
#  '海斯帕·甘普',
#  '纳西莎·马尔福',
#  '莱克里丝·布莱克',
#  '阿克图勒斯·布莱克三世',
#  '阿尔法德·布莱克',
#  '雷古勒斯·布莱克',
#  '雷古勒斯·布莱克一世',
#  '威基·泰克罗斯',
#  '幻影显形课指导教师',
#  '英国魔法部雇员',
#  '威尔克斯',
#  '威尔海姆·费歇尔',
#  '安东宁·多洛霍夫',
#  '多洛霍夫家族',
#  '奎妮·戈德斯坦',
#  '戈德斯坦家族',
#  '唐克斯家族',
#  '德鲁埃拉·罗齐尔',
#  '泰迪·卢平',
#  '罗齐尔家族',
#  '安布罗修·弗鲁姆',
#  '蜂蜜公爵',
#  '安德鲁·柯克',
#  '美国参议院',
#  '肖家族',
#  '劫猎者',
#  '菲尼亚斯·奈杰勒斯·布莱克',
#  '尤安·阿伯克龙比',
#  '尤里克·甘普',
#  '威森加摩首席魔法师',
#  '英国政府',
#  '魔法部部长',
#  '尼古拉斯·德·敏西-波平顿',
#  '亨利七世宫廷',
#  '无头猎手队',
#  '先遣警卫',
#  '卢平家族',
#  '泰德·卢平',
#  '莱尔·卢平',
#  '巴克比克',
#  '巴托罗缪·巴瑞波恩',
#  '肃清者',
#  '巴麦尊勋爵',
#  '英国',
#  '英国首相',
#  '麻瓜社会',
#  '布莱奇',
#  '布莱奇家庭',
#  '帕翠霞·斯廷森',
#  '弗兰克·隆巴顿',
#  '格朗宁公司',
#  '佩弗利尔家族',
#  '波特夫人（原姓弗利蒙）',
#  '莉莉·波特（原姓伊万斯）',
#  '波特瞭望站',
#  '德克·克莱斯韦',
#  '克莱斯韦夫人',
#  '妖精联络处',
#  '德拉科·马尔福一伙人',
#  '斯莱特林学院',
#  '格林格拉斯家族',
#  '达芙妮·格林格拉斯',
#  '德里安·普塞',
#  '德雷克',
#  '忒修斯·斯卡曼德',
#  '斯卡曼德夫人',
#  '莉塔·莱斯特兰奇',
#  '蒂娜·戈德斯坦',
#  '戈德里克·格兰芬多',
#  '决斗大师',
#  '霍格沃茨创办者',
#  '霍格沃茨教授',
#  '戴丽丝·德文特',
#  '治疗师',
#  '戴维·格杰恩',
#  '格杰恩家庭',
#  '史密斯先生',
#  '史密斯家族',
#  '托比亚·斯内普',
#  '斯内普家庭',
#  '普林斯家庭',
#  '艾琳·普林斯',
#  '拉道夫斯·莱斯特兰奇',
#  '拉巴斯坦·莱斯特兰奇',
#  '莱斯特兰奇',
#  '提贝卢斯',
#  '麦克拉根家庭',
#  '提贝卢斯·奥格登',
#  '奥格登家族',
#  '曼蒂·布洛贺',
#  '布洛贺家庭',
#  '杜戈尔·麦格雷格',
#  '麦格雷格先生',
#  '麦格雷格夫人',
#  '杜戈尔·麦格雷格的妻子',
#  '杜戈尔·麦格雷格的岳父',
#  '杜戈尔·麦格雷格的父亲',
#  '杜格德·麦克费尔',
#  '杰克·斯劳珀',
#  '杰弗里·胡珀',
#  '胡珀家庭',
#  '杰玛·法利',
#  '罗马尼亚火龙保护区',
#  '查莉蒂·威尔金森',
#  '傲罗',
#  '美国魔法国会主席',
#  '格丝尔达·玛奇班',
#  '巫师考试管理局',
#  '格洛普',
#  '弗里德瓦法',
#  '格罗根·斯顿普',
#  '塔特希尔龙卷风队',
#  '格韦诺格·琼斯',
#  '琼斯家族',
#  '霍利黑德哈比队',
#  '桃金娘·沃伦',
#  '沃伦先生',
#  '沃伦夫人',
#  '沃伦家庭',
#  '梅林',
#  '亚瑟王的宫廷',
#  '梅林爵士团',
#  '梅林达·波宾',
#  '波宾家庭',
#  '梅森',
#  '梅森家庭',
#  '梅森的妻子',
#  '加布丽·德拉库尔',
#  '古灵阁巫师银行',
#  '德拉库尔先生',
#  '德拉库尔家族',
#  '阿波琳·德拉库尔',
#  '破釜酒吧',
#  '破釜酒吧女老板',
#  '艾丽斯·隆巴顿',
#  '艾博夫人',
#  '艾博家族',
#  '隆巴顿家族',
#  '博金-博克',
#  '博金-博克店员',
#  '卡德摩斯·佩弗利尔',
#  '托马斯·里德尔',
#  '梅洛普·冈特',
#  '玛丽·里德尔',
#  '科维努斯·冈特',
#  '老汤姆·里德尔',
#  '莫芬·冈特',
#  '马沃罗·冈特',
#  '克拉布家族',
#  '卡西欧佩娅·布莱克',
#  '多瑞娅·布莱克',
#  '查勒斯·波特',
#  '维奥莱塔·伯斯德',
#  '西格纳斯·布莱克二世',
#  '阿克图勒斯·布莱克',
#  '阿拉明塔·梅利弗伦·布莱克',
#  '马里厄斯·布莱克',
#  '法里斯·斯帕文',
#  '波佩图阿·范考特',
#  '发明家',
#  '泰瑞·布特',
#  '布特家族',
#  '洛丽丝夫人',
#  '阿格斯·费尔奇',
#  '洛肯·麦克莱德',
#  '爱洛伊丝·米德根',
#  '米德根家庭',
#  '爱米琳·万斯',
#  '特拉弗斯',
#  '玛丽·乔安西',
#  '第二塞勒姆教堂',
#  '德思礼先生',
#  '玛莎·斯图尔特',
#  '格雷维斯家族',
#  '调查组',
#  '魔法安全主管',
#  '魔法法律执行部',
#  '魔法法律执行部司长',
#  '瑟拉菲娜·皮奎利',
#  '皮奎利家族',
#  '长角水蛇',
#  '瑟达德·冯塔纳',
#  '张先生',
#  '张夫人',
#  '张氏家庭',
#  '拉文克劳魁地奇球队',
#  '麻瓜',
#  '秋·张的丈夫',
#  '米兰达·戈沙克',
#  '坦维斯尔·戈沙克',
#  '戈沙克先生',
#  '戈沙克夫人',
#  '罗米达·戈沙克',
#  '迪亚德玛·戈沙克',
#  '变形学系',
#  '埃尔科特家族',
#  '晚于2008年但早于2017年)',
#  '格兰芬多学院院长(早于1975年－1998年)',
#  '罗斯先生',
#  '罗斯夫人',
#  '英国魔法部(曾经)',
#  '霍格沃茨魔法学校副校长(?－1998年)',
#  '霍格沃茨魔法学校变形学系主任(1956年－1998年)',
#  '霍格沃茨魔法学校校长(1998年',
#  '魔法法律执行司雇员',
#  '米里森·巴格诺',
#  '戈德斯坦先生',
#  '戈德斯坦夫人',
#  '神奇动物学家',
#  '魔法生物管理控制司',
#  '魔法生物管理控制司野兽办公室',
#  '维努西亚·奎克利',
#  '英国魔法部部长',
#  '格兰杰先生',
#  '格兰杰夫人',
#  '格兰杰家庭',
#  '罗伊斯顿·埃德温德',
#  'ICWQC国际主管',
#  '澳大利亚魁地奇国家队追球手',
#  '罗伊登·波克',
#  '罗伊纳·拉文克劳',
#  '拉文克劳家族',
#  '海莲娜·拉文克劳',
#  '罗伯特·葛林斯汀奇',
#  '家养小精灵解放阵线',
#  '查德里火炮队',
#  '泰丝',
#  '莫丽·韦斯莱，原姓普威特',
#  '韦斯莱魔法把戏坊雇员',
#  '米勒娃',
#  '麦格先生',
#  '麦格夫人',
#  '老罗伯特·麦格的母亲',
#  '老罗伯特·麦格的父亲',
#  '考迈克·奥布莱恩',
#  '肯尼思·托勒',
#  '胖修士',
#  '天主教堂',
#  '芒戈·麦克达夫',
#  '布斯巴顿魔法学院',
#  '芬里尔·格雷伯克',
#  '搜捕队员',
#  '狼人军队',
#  '食死徒(非正式成员)',
#  '苏珊·博恩斯',
#  '博恩斯先生',
#  '博恩斯夫人',
#  '博恩斯家庭',
#  '埃德加·博恩斯',
#  '埃德加·博恩斯的孩子',
#  '阿米莉亚·博恩斯',
#  '莉莎·杜平',
#  '莎莉安·波克斯',
#  '波克斯家庭',
#  '莫恩',
#  '莫恩家族',
#  '莫迪丝蒂·巴瑞波恩的兄弟姐妹',
#  '莫迪丝蒂·巴瑞波恩的母亲',
#  '莫迪丝蒂·巴瑞波恩的父亲',
#  '劫盗者',
#  '唐克斯家庭',
#  '霍普·卢平',
#  '乌尔苏拉·弗林特',
#  '卡莉朵拉·布莱克',
#  '埃拉朵拉·布莱克',
#  '天狼星·布莱克一世',
#  '查莉丝·布莱克',
#  '约拉·布莱克',
#  '菲尼亚斯·布莱克',
#  '贝尔维娜·布莱克',
#  '赫伯特·博克',
#  '鲍勃·希钦斯',
#  '斯莱特林家族',
#  '冈特家族',
#  '蒙太',
#  '蒙太家庭',
#  '西尔瓦努斯·凯特尔伯恩',
#  '凯特尔伯恩先生',
#  '凯特尔伯恩夫人',
#  '凯特尔伯恩家庭',
#  '霍格沃茨魔药课教师',
#  '霍格沃茨黑魔法防御术教授',
#  '鲁弗斯·斯克林杰',
#  '西格纳斯·布莱克',
#  '西比尔·特里劳尼',
#  '卡桑德拉·特里劳尼',
#  '希格尔博特姆',
#  '特里劳尼先生',
#  '特里劳尼夫人',
#  '特里劳尼家族',
#  '斐尼甘先生',
#  '斐尼甘夫人',
#  '斐尼甘家庭',
#  '爱尔兰',
#  '菲戈',
#  '西莫·斐尼甘的父亲',
#  '莫莉·韦斯莱',
#  '詹姆·波特一世',
#  '赫敏·韦斯莱',
#  '伊尔弗莫尼魔法学校校长及创办者',
#  '石匠',
#  '哈德温·波特',
#  '罗尔斯顿·波特',
#  '艾欧兰斯·佩弗利尔',
#  '诺比·利奇',
#  '贝希尔德·罗氏',
#  '莱斯特兰奇家族',
#  '赫尔加·赫奇帕奇',
#  '赫奇帕奇家族',
#  '赫普兹巴·史密斯',
#  '赫尔穆特·魏斯',
#  '家养小精灵权益促进会',
#  '赫托克·达格沃斯-格兰杰',
#  '阿不思·波特',
#  '魔法法律执行司副司长',
#  '赫斯菲斯托斯·戈尔',
#  '路威',
#  '他的同伙',
#  '斯梅廷中学',
#  '达力·德思礼的孩子',
#  '《预言家日报》',
#  '《预言家日报》魁地奇资深记者',
#  '普威特家庭',
#  '霍利黑德哈比队魁地奇球员',
#  '变形学系系主任',
#  '国际巫师联合会',
#  '坎德拉·邓布利多',
#  '康奈利·福吉',
#  '珀西瓦尔·邓布利多',
#  '老魔杖',
#  '邓布利多家族',
#  '阿不福思·邓布利多',
#  '阿利安娜·邓布利多',
#  '霍诺利亚',
#  '魔法法律委员会',
#  '猪头酒吧',
#  '阿切尔·埃弗蒙德',
#  '阿拉戈克',
#  '禁林八眼巨蛛群落',
#  '莫萨格',
#  '阿莫斯·迪戈里',
#  '迪戈里夫人',
#  '阿诺德·皮斯古德',
#  '打击手',
#  '记忆注销员(曾经)',
#  '雅各布·科瓦尔斯基',
#  '科瓦尔斯基先生',
#  '科瓦尔斯基烘焙坊店主',
#  '美国远征军士兵',
#  '莫顿·戴尔罐头厂工人(曾经)',
#  '雅各布·科瓦尔斯基的兄弟',
#  '雅各布·科瓦尔斯基的祖母',
#  '雅各布·科瓦尔斯基的祖父',
#  '伊尔玛·布莱克',
#  '梅拉尼娅·布莱克',
#  '霍滕西亚·米里法特',
#  '布特先生',
#  '布特夫人',
#  '韦恩·霍普金斯',
#  '马库斯·弗林特',
#  '弗林特家族',
#  '马法尔达·霍普柯克',
#  '马琳·麦金农',
#  '麦金农家庭',
#  '格洛普的父亲',
#  '海格先生',
#  '海格家庭',
#  '霍格沃茨保护神奇动物课',
#  '霍格沃茨钥匙保管员和猎场看守',
#  '傲罗办公室主任(曾经)',
#  '魔法部部长(曾经)',
#  '鲁弗斯·福吉',
#  '福吉夫人',
#  '福吉家庭',
#  '鲍曼·赖特的父亲',
#  '赖特夫人',
#  '鲍曼·赖特',
#  '齐格蒙特·巴奇',
#  '巴奇夫人',
#  '药剂师']

# %%
get_randomwalk('哈利·波特', 5)
# Out:
# ['哈利·波特', '乔治·韦斯莱', '吉米·珀克斯', '格兰芬多魁地奇球队', '查理·韦斯莱']

# %%
gamma = 10 # 每个节点作为起始点生成随机游走序列个数
walk_length = 5 # 随机游走序列最大长度

# %%
random_walks = []

for n in tqdm(all_nodes): # 遍历每个节点
    for i in range(gamma): # 每个节点作为起始点生成gamma个随机游走序列
        random_walks.append(get_randomwalk(n, walk_length))
# Out:
# 100%|██████████| 648/648 [00:00<00:00, 13987.13it/s]

# %%
# 生成随机游走序列个数
len(random_walks)
# Out:
# 6480

# %%
random_walks[1]
# Out:
# ['C.沃林顿', '斯莱特林魁地奇球队', '马库斯·弗林特', '斯莱特林', '纳西莎·马尔福']

# %%
from gensim.models import Word2Vec # 自然语言处理

# %%
model = Word2Vec(vector_size=256, # Embedding维数
                 window=4, # 窗口宽度
                 sg=1, # Skip-Gram
                 hs=0, # 不加分层softmax
                 negative=10, # 负采样
                 alpha=0.03,  # 初始学习率
                 min_alpha=0.0007, # 最小学习率
                 seed=14 # 随机数种子
                )

# %%
# 用随机游走序列构建词汇表
model.build_vocab(random_walks, progress_per=2)

# %%
# 训练（耗时1分钟左右）
model.train(random_walks, total_examples=model.corpus_count, epochs=50, report_delay=1)
# Out:
# (1167856, 1412200)

# %%
# 查看某个节点的Embedding
model.wv.get_vector('哈利·波特').shape
# Out:
# (256,)

# %%
model.wv.get_vector('哈利·波特')
# Out:
# array([ 0.04805676, -0.08903797, -0.06913359, -0.16911325,  0.2460473 ,
#        -0.05157926, -0.30803734,  0.25270435, -0.32293865, -0.28934702,
#         0.10030584, -0.43395793,  0.10813572,  0.07096055, -0.1275813 ,
#         0.18640755, -0.24325544,  0.38442722,  0.08912934,  0.01001695,
#         0.07745539, -0.10149032, -0.03364048, -0.23008789, -0.55350745,
#        -0.3487958 , -0.03271427, -0.1618109 , -0.24214289,  0.02543607,
#        -0.20444599,  0.40515772, -0.12824088, -0.09466792, -0.31554168,
#         0.0943582 ,  0.16531762, -0.0716354 , -0.39589322, -0.33008033,
#         0.13744406,  0.5701074 ,  0.46739894,  0.14855224,  0.20503438,
#        -0.04841891, -0.02022275,  0.21909021, -0.15327482,  0.15959038,
#         0.01148046, -0.17986596, -0.2644588 , -0.6122868 ,  0.19222453,
#        -0.00251377, -0.13353056, -0.05891381, -0.05234259, -0.4432555 ,
#         0.05426223, -0.2857316 , -0.26033476,  0.5164521 , -0.17262267,
#         0.1568728 ,  0.3926177 ,  0.05532842, -0.28744477, -0.2435302 ,
#         0.2674407 ,  0.05819947,  0.13457194, -0.0806131 ,  0.25249264,
#        -0.04873388, -0.05511827, -0.19179997,  0.10182232, -0.292417  ,
#        -0.24005084,  0.12572707,  0.09855176,  0.05958138, -0.13106923,
#         0.11992341,  0.088035  , -0.24055892,  0.19347204,  0.36659908,
#        -0.28058907,  0.24864462,  0.28200883, -0.09421657,  0.11713046,
#        -0.14120291, -0.09165947,  0.03423906, -0.63341904,  0.294     ,
#        -0.07111367,  0.17310297, -0.02346866, -0.17818214,  0.16926555,
#        -0.03770809, -0.46205917,  0.32204878,  0.18031137,  0.15783176,
#         0.02506694, -0.11318363, -0.07874452,  0.43379113,  0.21873266,
#        -0.15753049, -0.06519846,  0.03142596, -0.09076563, -0.07513928,
#         0.30942884, -0.47149307, -0.39444882, -0.29485962,  0.01102977,
#         0.07695943, -0.1571389 ,  0.05331865,  0.27132842,  0.1741683 ,
#         0.09836551,  0.14170143, -0.08516729,  0.04665713,  0.22012384,
#         0.07075066, -0.11657819,  0.4978573 , -0.03411332,  0.09910375,
#         0.35834897, -0.06682551,  0.28588608,  0.52082497, -0.16726598,
#        -0.21432224,  0.06167748, -0.12493978,  0.27802235, -0.1520782 ,
#         0.1439437 ,  0.20709662, -0.32046643, -0.17682317, -0.15948848,
#        -0.03551967, -0.19162436, -0.27355167, -0.17305383,  0.00766122,
#         0.12243503, -0.08694317, -0.35627967,  0.01716664,  0.09939016,
#        -0.28040868, -0.03290847, -0.03689643,  0.07492162,  0.0468255 ,
#         0.13749753, -0.1657545 , -0.14066677, -0.3035047 ,  0.12217454,
#        -0.18820222,  0.42310092, -0.21390717, -0.01236838,  0.45386693,
#        -0.12809716,  0.02676949,  0.05729448, -0.09426851,  0.23238872,
#        -0.13284257, -0.31590256, -0.16118605,  0.00487887,  0.27086607,
#        -0.00163219, -0.08244391,  0.03520729,  0.09746733,  0.24062131,
#         0.39181778,  0.2162064 , -0.11019754, -0.07168041, -0.45266747,
#         0.10348622,  0.12280543,  0.50812584,  0.10405229,  0.17453155,
#         0.05810889,  0.18377355, -0.23264161,  0.08460348, -0.00267093,
#         0.14812423,  0.09416741, -0.29877573, -0.11483677,  0.13670726,
#        -0.08425911,  0.1479227 , -0.02272527,  0.24085139,  0.29189196,
#        -0.36084238, -0.24976018, -0.08647628, -0.2618741 , -0.33564842,
#         0.09390179, -0.0066776 ,  0.31702548,  0.3213618 ,  0.34324083,
#         0.02250283,  0.02264171, -0.03689476, -0.18235269, -0.25339314,
#         0.10852095, -0.27603725,  0.42070383, -0.16541384, -0.04178408,
#        -0.2038241 ,  0.06574272,  0.17699628,  0.05568152, -0.2610169 ,
#         0.45613554, -0.40650627, -0.25203636,  0.09344048, -0.0857359 ,
#         0.04910134,  0.11722825, -0.17551222,  0.16132799, -0.25545797,
#         0.12482138], dtype=float32)

# %%
# 找相似词语
model.wv.similar_by_word('哈利·波特')
# Out:
# [('达力·德思礼的孩子', 0.4988202452659607),
#  ('格朗宁公司的上班族', 0.48592865467071533),
#  ('家庭主妇', 0.4788525402545929),
#  ('路易斯·韦斯莱', 0.47627004981040955),
#  ('哈德温·波特', 0.4759107828140259),
#  ('德思礼夫人', 0.4644019901752472),
#  ('达力的孩子', 0.4637949764728546),
#  ('沃伦家庭', 0.46323665976524353),
#  ('斯梅廷中学', 0.4615587294101715),
#  ('德拉库尔先生', 0.4590758979320526)]
