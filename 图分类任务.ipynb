# %%
import torch
from torch_geometric.datasets import TUDataset

# %%
dataset = TUDataset(root='C:/folder/code/jupyter/PyG/data', name='ENZYMES',transform=NormalizeFeatures())
print()
print(f'Dataset: {dataset}:')
print('====================')
print(f'Number of graphs: {len(dataset)}')
print(f'Number of features: {dataset.num_features}')
print(f'Number of classes: {dataset.num_classes}')
print('====================')
data=dataset[0]
print(data)
# Out:
# Dataset: ENZYMES(600):
# ====================
# Number of graphs: 600
# Number of features: 3
# Number of classes: 6
# ====================
# Data(edge_index=[2, 168], x=[37, 3], y=[1])

# %%
train_dataset = dataset
print(f'Number of training graphs: {len(train_dataset)}')
# Out:
# Number of training graphs: 600

# %%
from torch_geometric.loader import DataLoader

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)#图也可以进行batch，拼接邻接矩阵和数据没有对其做统一操作

for step, data in enumerate(train_loader):
    print(f'Step {step + 1}:')
    print('=======')
    print(f'Number of graphs in the current batch: {data.num_graphs}')
    print(data)
    print()
# Out:
# Step 1:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 7984], x=[2147, 3], y=[64], batch=[2147], ptr=[65])
#
# Step 2:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 7394], x=[1985, 3], y=[64], batch=[1985], ptr=[65])
#
# Step 3:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 8618], x=[2257, 3], y=[64], batch=[2257], ptr=[65])
#
# Step 4:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 7190], x=[1933, 3], y=[64], batch=[1933], ptr=[65])
#
# Step 5:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 8504], x=[2298, 3], y=[64], batch=[2298], ptr=[65])
#
# Step 6:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 7632], x=[1966, 3], y=[64], batch=[1966], ptr=[65])
#
# Step 7:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 8336], x=[2151, 3], y=[64], batch=[2151], ptr=[65])
#
# Step 8:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 8426], x=[2155, 3], y=[64], batch=[2155], ptr=[65])
#
# Step 9:
# =======
# Number of graphs in the current batch: 64
# DataBatch(edge_index=[2, 8114], x=[2066, 3], y=[64], batch=[2066], ptr=[65])
#
# Step 10:
# =======
# Number of graphs in the current batch: 24
# DataBatch(edge_index=[2, 2366], x=[622, 3], y=[24], batch=[622], ptr=[25])

# %% [markdown]
# 图分类仍让是对节点进行嵌入，只不过最后增加一个聚合节点特征的操作
# 把各个节点特征汇总成全局特征就相当于得到了整个图的编码：

# %%
from torch.nn import Linear
import torch.nn.functional as F
from torch_geometric.nn import GCNConv
from torch_geometric.nn import global_mean_pool

# %%
class GCN(torch.nn.Module):
    def __init__(self, hidden_channels):
        super(GCN, self).__init__()
        torch.manual_seed(1)
        self.conv1 = GCNConv(dataset.num_node_features, hidden_channels)
        self.conv2 = GCNConv(hidden_channels, hidden_channels)
        self.conv3 = GCNConv(hidden_channels, hidden_channels)
        self.lin = Linear(hidden_channels, dataset.num_classes)
        
    def forward(self, x, edge_index, batch):
        # 1.对各节点进行编码
        x = self.conv1(x, edge_index)
        x = x.relu()
        x = self.conv2(x, edge_index)
        x = x.relu()
        x = self.conv3(x, edge_index)

        # 2. 平均操作
        x = global_mean_pool(x, batch)  # [batch_size, hidden_channels]

        # 3. 输出
        x = F.dropout(x, p=0.5, training=self.training)
        x = self.lin(x)
        
        return x

# %%
model = GCN(hidden_channels=64)
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
criterion = torch.nn.CrossEntropyLoss()

# %%
def train():
    model.train()

    for data in train_loader:  # Iterate in batches over the training dataset.
        out = model(data.x, data.edge_index, data.batch)  # Perform a single forward pass.
        loss = criterion(out, data.y)  # Compute the loss.
        loss.backward()  # Derive gradients.
        optimizer.step()  # Update parameters based on gradients.
        optimizer.zero_grad()  # Clear gradients.

# %%
def test(loader):
    model.eval()

    correct = 0
    for data in loader:  # Iterate in batches over the training/test dataset.
        out = model(data.x, data.edge_index, data.batch)  
        pred = out.argmax(dim=1)  # Use the class with highest probability.
        correct += int((pred == data.y).sum())  # Check against ground-truth labels.
    return correct / len(loader.dataset)  # Derive ratio of correct predictions.

# %%
for epoch in range(1, 171):
    train()
    train_acc = test(train_loader)
    print(f'Epoch: {epoch:03d}, Train Acc: {train_acc:.4f}')
# Out:
# Epoch: 001, Train Acc: 0.1933
# Epoch: 002, Train Acc: 0.2217
# Epoch: 003, Train Acc: 0.2450
# Epoch: 004, Train Acc: 0.2450
# Epoch: 005, Train Acc: 0.2600
# Epoch: 006, Train Acc: 0.2667
# Epoch: 007, Train Acc: 0.2733
# Epoch: 008, Train Acc: 0.2450
# Epoch: 009, Train Acc: 0.2833
# Epoch: 010, Train Acc: 0.2850
# Epoch: 011, Train Acc: 0.2833
# Epoch: 012, Train Acc: 0.2817
# Epoch: 013, Train Acc: 0.2733
# Epoch: 014, Train Acc: 0.3000
# Epoch: 015, Train Acc: 0.2900
# Epoch: 016, Train Acc: 0.2833
# Epoch: 017, Train Acc: 0.3033
# Epoch: 018, Train Acc: 0.3000
# Epoch: 019, Train Acc: 0.2867
# Epoch: 020, Train Acc: 0.2817
# Epoch: 021, Train Acc: 0.3133
# Epoch: 022, Train Acc: 0.2900
# Epoch: 023, Train Acc: 0.3033
# Epoch: 024, Train Acc: 0.2833
# Epoch: 025, Train Acc: 0.2783
# Epoch: 026, Train Acc: 0.2833
# Epoch: 027, Train Acc: 0.3283
# Epoch: 028, Train Acc: 0.2650
# Epoch: 029, Train Acc: 0.3150
# Epoch: 030, Train Acc: 0.2983
# Epoch: 031, Train Acc: 0.2867
# Epoch: 032, Train Acc: 0.3300
# Epoch: 033, Train Acc: 0.3183
# Epoch: 034, Train Acc: 0.3017
# Epoch: 035, Train Acc: 0.3200
# Epoch: 036, Train Acc: 0.3350
# Epoch: 037, Train Acc: 0.2800
# Epoch: 038, Train Acc: 0.3233
# Epoch: 039, Train Acc: 0.3400
# Epoch: 040, Train Acc: 0.2933
# Epoch: 041, Train Acc: 0.3067
# Epoch: 042, Train Acc: 0.3100
# Epoch: 043, Train Acc: 0.3317
# Epoch: 044, Train Acc: 0.3250
# Epoch: 045, Train Acc: 0.3100
# Epoch: 046, Train Acc: 0.3250
# Epoch: 047, Train Acc: 0.3400
# Epoch: 048, Train Acc: 0.3333
# Epoch: 049, Train Acc: 0.3233
# Epoch: 050, Train Acc: 0.3233
# Epoch: 051, Train Acc: 0.3250
# Epoch: 052, Train Acc: 0.3300
# Epoch: 053, Train Acc: 0.3167
# Epoch: 054, Train Acc: 0.3250
# Epoch: 055, Train Acc: 0.3283
# Epoch: 056, Train Acc: 0.3233
# Epoch: 057, Train Acc: 0.3117
# Epoch: 058, Train Acc: 0.3383
# Epoch: 059, Train Acc: 0.3267
# Epoch: 060, Train Acc: 0.3167
# Epoch: 061, Train Acc: 0.3367
# Epoch: 062, Train Acc: 0.3417
# Epoch: 063, Train Acc: 0.3267
# Epoch: 064, Train Acc: 0.3300
# Epoch: 065, Train Acc: 0.3283
# Epoch: 066, Train Acc: 0.3317
# Epoch: 067, Train Acc: 0.3050
# Epoch: 068, Train Acc: 0.3333
# Epoch: 069, Train Acc: 0.3267
# Epoch: 070, Train Acc: 0.3200
# Epoch: 071, Train Acc: 0.3333
# Epoch: 072, Train Acc: 0.3483
# Epoch: 073, Train Acc: 0.3317
# Epoch: 074, Train Acc: 0.3467
# Epoch: 075, Train Acc: 0.3300
# Epoch: 076, Train Acc: 0.3417
# Epoch: 077, Train Acc: 0.3133
# Epoch: 078, Train Acc: 0.3333
# Epoch: 079, Train Acc: 0.3200
# Epoch: 080, Train Acc: 0.3467
# Epoch: 081, Train Acc: 0.3350
# Epoch: 082, Train Acc: 0.3400
# Epoch: 083, Train Acc: 0.3400
# Epoch: 084, Train Acc: 0.3300
# Epoch: 085, Train Acc: 0.3333
# Epoch: 086, Train Acc: 0.3367
# Epoch: 087, Train Acc: 0.3317
# Epoch: 088, Train Acc: 0.3333
# Epoch: 089, Train Acc: 0.3417
# Epoch: 090, Train Acc: 0.3383
# Epoch: 091, Train Acc: 0.3167
# Epoch: 092, Train Acc: 0.3450
# Epoch: 093, Train Acc: 0.3450
# Epoch: 094, Train Acc: 0.3467
# Epoch: 095, Train Acc: 0.3400
# Epoch: 096, Train Acc: 0.3450
# Epoch: 097, Train Acc: 0.3467
# Epoch: 098, Train Acc: 0.3383
# Epoch: 099, Train Acc: 0.3400
# Epoch: 100, Train Acc: 0.3467
# Epoch: 101, Train Acc: 0.3350
# Epoch: 102, Train Acc: 0.3367
# Epoch: 103, Train Acc: 0.3217
# Epoch: 104, Train Acc: 0.3400
# Epoch: 105, Train Acc: 0.3300
# Epoch: 106, Train Acc: 0.3417
# Epoch: 107, Train Acc: 0.3500
# Epoch: 108, Train Acc: 0.3417
# Epoch: 109, Train Acc: 0.3350
# Epoch: 110, Train Acc: 0.3317
# Epoch: 111, Train Acc: 0.3317
# Epoch: 112, Train Acc: 0.3383
# Epoch: 113, Train Acc: 0.3400
# Epoch: 114, Train Acc: 0.3400
# Epoch: 115, Train Acc: 0.3417
# Epoch: 116, Train Acc: 0.3467
# Epoch: 117, Train Acc: 0.3267
# Epoch: 118, Train Acc: 0.3450
# Epoch: 119, Train Acc: 0.3350
# Epoch: 120, Train Acc: 0.3483
# Epoch: 121, Train Acc: 0.3350
# Epoch: 122, Train Acc: 0.3400
# Epoch: 123, Train Acc: 0.3300
# Epoch: 124, Train Acc: 0.3383
# Epoch: 125, Train Acc: 0.3283
# Epoch: 126, Train Acc: 0.3383
# Epoch: 127, Train Acc: 0.3533
# Epoch: 128, Train Acc: 0.3450
# Epoch: 129, Train Acc: 0.3383
# Epoch: 130, Train Acc: 0.3367
# Epoch: 131, Train Acc: 0.3383
# Epoch: 132, Train Acc: 0.3383
# Epoch: 133, Train Acc: 0.3333
# Epoch: 134, Train Acc: 0.3367
# Epoch: 135, Train Acc: 0.3467
# Epoch: 136, Train Acc: 0.3367
# Epoch: 137, Train Acc: 0.3433
# Epoch: 138, Train Acc: 0.3433
# Epoch: 139, Train Acc: 0.3550
# Epoch: 140, Train Acc: 0.3517
# Epoch: 141, Train Acc: 0.3483
# Epoch: 142, Train Acc: 0.3450
# Epoch: 143, Train Acc: 0.3450
# Epoch: 144, Train Acc: 0.3433
# Epoch: 145, Train Acc: 0.3367
# Epoch: 146, Train Acc: 0.3517
# Epoch: 147, Train Acc: 0.3433
# Epoch: 148, Train Acc: 0.3300
# Epoch: 149, Train Acc: 0.3417
# Epoch: 150, Train Acc: 0.3367
# Epoch: 151, Train Acc: 0.3500
# Epoch: 152, Train Acc: 0.3617
# Epoch: 153, Train Acc: 0.3433
# Epoch: 154, Train Acc: 0.3500
# Epoch: 155, Train Acc: 0.3383
# Epoch: 156, Train Acc: 0.3483
# Epoch: 157, Train Acc: 0.3467
# Epoch: 158, Train Acc: 0.3500
# Epoch: 159, Train Acc: 0.3450
# Epoch: 160, Train Acc: 0.3367
# Epoch: 161, Train Acc: 0.3517
# Epoch: 162, Train Acc: 0.3583
# Epoch: 163, Train Acc: 0.3483
# Epoch: 164, Train Acc: 0.3567
# Epoch: 165, Train Acc: 0.3517
# Epoch: 166, Train Acc: 0.3533
# Epoch: 167, Train Acc: 0.3483
# Epoch: 168, Train Acc: 0.3517
# Epoch: 169, Train Acc: 0.3567
# Epoch: 170, Train Acc: 0.3567
